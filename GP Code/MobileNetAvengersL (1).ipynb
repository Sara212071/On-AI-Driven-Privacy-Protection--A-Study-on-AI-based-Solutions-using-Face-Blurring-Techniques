# %% [markdown]
# #IMPORT

# %%
import pandas as pd
from tqdm import tqdm, trange
import numpy as np
import os
import gc
import time
import cv2
from matplotlib import pyplot as plt
from skimage.transform import resize
import seaborn as sns

from keras.applications.mobilenet import preprocess_input as preprocess_input_v1, decode_predictions as decode_predictions_v1
from keras.utils import load_img, img_to_array, to_categorical
from keras.applications import MobileNet
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, GlobalAveragePooling2D
from keras.optimizers import Adam, AdamW, RMSprop, SGD
from keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import F1Score
from keras.callbacks import EarlyStopping, LearningRateScheduler
import tensorflow as tf

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score

# %% [markdown]
# #Dataset

# %%
IMAGES_SRC = r"C:\Users\saraa\Downloads\avengers"

# %%
print(os.listdir(IMAGES_SRC))
# Out:
# ['bruce_banner (Mark Ruffalo)', 'clint_barton (Jeremy Renner)', 'Natasha_Romanoff (Scarlett Johansson)', 'steve_rogers (Chris Evans)', 'thor (Chris Hemsworth)', 'tony_stark (Robert Downey Jr.)']

# %%
image = os.listdir(IMAGES_SRC)

# %% [markdown]
# #Preprocessing

# %%
face = []
for c in image:
    i = image.index(c)
    path = os.path.join(IMAGES_SRC, c)
    if os.path.exists(path):
        for img in os.listdir(path):
            img_path = os.path.join(path, img)
            im = cv2.imread(img_path)
            if im is not None:
                im = cv2.resize(im, (224, 224))  # Resize the image
                face.append([im, i])
            else:
                print(f"Failed to load image at {img_path}")
    else:
        print(f"Directory not found: {path}")

# %%
X=[]
Y=[]
for x,y in face:
    X.append(x)
    Y.append(y)

# %%
x=np.array(X)
y=np.array(Y)
print(x.shape,y.shape)
# Out:
# (916, 224, 224, 3) (916,)

# %%
encoder = OneHotEncoder(dtype=np.float32)

# %%
# Fit and transform the data
encoded_Y = encoder.fit_transform(y.reshape(-1, 1))
encoded_Y = encoded_Y.toarray()

# %%
encoded_Y.shape
# Out:
# (916, 6)

# %% [markdown]
# #train-test

# %%
X1_train, X1_test,Y1_train,Y1_test = train_test_split(x,encoded_Y, test_size=0.3, random_state=30)

# %% [markdown]
# #Modeling

# %% [markdown]
# #Training

# %%
from keras.applications import MobileNet
from keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from keras.models import Model
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Load the MobileNet model, pretrained on ImageNet
mobilenet_mdl = MobileNet(
    include_top=False,
    input_shape=(224, 224, 3),
    weights='imagenet'
)

# Using the output of the penultimate layer
base_input = mobilenet_mdl.input
base_output = mobilenet_mdl.layers[-2].output

# Adding the new top layers
top_model = GlobalAveragePooling2D(data_format="channels_last")(base_output)
top_model = Dense(1024, activation="relu")(top_model)
top_model = BatchNormalization()(top_model)  # Added batch normalization
top_model = Dropout(0.3)(top_model)  # Increased dropout rate
top_model = Dense(1000, activation="relu")(top_model)
top_model = BatchNormalization()(top_model)  # Added batch normalization
top_model = Dropout(0.3)(top_model)  # Increased dropout rate
top_model = Dense(6, activation="softmax")(top_model)

# Create the new model
model = Model(inputs=base_input, outputs=top_model)

# Compile the model with an optimizer and loss function
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks for early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1, mode='min', min_lr=0.0001)

# Fit the model
result = model.fit(
    X1_train, Y1_train,
    epochs=50,
    batch_size=32,
    validation_data=(X1_test, Y1_test),
    callbacks=[early_stopping, reduce_lr]  # Added callbacks
)
# Out:
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.5758 - loss: 1.4403 - val_accuracy: 0.1527 - val_loss: 46.1277 - learning_rate: 0.0010
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.8619 - loss: 0.5158 - val_accuracy: 0.4655 - val_loss: 8.7678 - learning_rate: 0.0010
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9470 - loss: 0.1819 - val_accuracy: 0.7927 - val_loss: 2.0193 - learning_rate: 0.0010
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.9649 - loss: 0.1148 - val_accuracy: 0.6327 - val_loss: 4.6717 - learning_rate: 0.0010
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.9874 - loss: 0.0420 - val_accuracy: 0.7964 - val_loss: 1.6802 - learning_rate: 0.0010
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9698 - loss: 0.0938 - val_accuracy: 0.7964 - val_loss: 1.9430 - learning_rate: 0.0010
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9781 - loss: 0.0709 - val_accuracy: 0.8582 - val_loss: 1.3730 - learning_rate: 0.0010
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.9871 - loss: 0.0364 - val_accuracy: 0.8473 - val_loss: 1.3141 - learning_rate: 0.0010
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9875 - loss: 0.0668 - val_accuracy: 0.8545 - val_loss: 1.6884 - learning_rate: 0.0010
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9762 - loss: 0.0793 - val_accuracy: 0.7418 - val_loss: 2.4818 - learning_rate: 0.0010
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.9820 - loss: 0.0447 - val_accuracy: 0.6436 - val_loss: 4.6844 - learning_rate: 0.0010
# Epoch 12/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.9912 - loss: 0.0168 - val_accuracy: 0.8691 - val_loss: 1.0046 - learning_rate: 0.0010
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.9962 - loss: 0.0068 - val_accuracy: 0.9527 - val_loss: 0.3744 - learning_rate: 0.0010
# Epoch 14/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9935 - loss: 0.0167 - val_accuracy: 0.9309 - val_loss: 0.4588 - learning_rate: 0.0010
# Epoch 15/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9905 - loss: 0.0270 - val_accuracy: 0.9200 - val_loss: 0.5600 - learning_rate: 0.0010
# Epoch 16/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9809 - loss: 0.0432 - val_accuracy: 0.8364 - val_loss: 1.3344 - learning_rate: 0.0010
# Epoch 17/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.9852 - loss: 0.0352 - val_accuracy: 0.8291 - val_loss: 1.3501 - learning_rate: 0.0010
# Epoch 18/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9709 - loss: 0.1239
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9707 - loss: 0.1242 - val_accuracy: 0.9018 - val_loss: 0.6785 - learning_rate: 0.0010
# Epoch 19/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9885 - loss: 0.0621 - val_accuracy: 0.9127 - val_loss: 0.5061 - learning_rate: 2.0000e-04
# Epoch 20/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9909 - loss: 0.0327 - val_accuracy: 0.9345 - val_loss: 0.3416 - learning_rate: 2.0000e-04
# Epoch 21/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9967 - loss: 0.0146 - val_accuracy: 0.9564 - val_loss: 0.2691 - learning_rate: 2.0000e-04
# Epoch 22/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9970 - loss: 0.0068 - val_accuracy: 0.9636 - val_loss: 0.2029 - learning_rate: 2.0000e-04
# Epoch 23/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9974 - loss: 0.0060 - val_accuracy: 0.9636 - val_loss: 0.1849 - learning_rate: 2.0000e-04
# Epoch 24/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.9993 - loss: 0.0030 - val_accuracy: 0.9709 - val_loss: 0.1814 - learning_rate: 2.0000e-04
# Epoch 25/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.9976 - loss: 0.0075 - val_accuracy: 0.9709 - val_loss: 0.1679 - learning_rate: 2.0000e-04
# Epoch 26/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9967 - loss: 0.0051 - val_accuracy: 0.9745 - val_loss: 0.1737 - learning_rate: 2.0000e-04
# Epoch 27/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9999 - loss: 7.5293e-04 - val_accuracy: 0.9745 - val_loss: 0.1713 - learning_rate: 2.0000e-04
# Epoch 28/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9999 - loss: 8.9809e-04 - val_accuracy: 0.9673 - val_loss: 0.1688 - learning_rate: 2.0000e-04
# Epoch 29/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9999 - loss: 5.3045e-04 - val_accuracy: 0.9636 - val_loss: 0.1644 - learning_rate: 2.0000e-04
# Epoch 30/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9636 - val_loss: 0.1573 - learning_rate: 2.0000e-04
# Epoch 31/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9999 - loss: 0.0020 - val_accuracy: 0.9673 - val_loss: 0.1517 - learning_rate: 2.0000e-04
# Epoch 32/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9972 - loss: 0.0080 - val_accuracy: 0.9636 - val_loss: 0.1469 - learning_rate: 2.0000e-04
# Epoch 33/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9999 - loss: 0.0030 - val_accuracy: 0.9564 - val_loss: 0.1615 - learning_rate: 2.0000e-04
# Epoch 34/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9999 - loss: 8.1927e-04 - val_accuracy: 0.9527 - val_loss: 0.1697 - learning_rate: 2.0000e-04
# Epoch 35/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9564 - val_loss: 0.1649 - learning_rate: 2.0000e-04
# Epoch 36/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9999 - loss: 7.3445e-04 - val_accuracy: 0.9636 - val_loss: 0.1581 - learning_rate: 2.0000e-04
# Epoch 37/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9999 - loss: 0.0014
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0001.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9999 - loss: 0.0015 - val_accuracy: 0.9527 - val_loss: 0.1625 - learning_rate: 2.0000e-04
# Epoch 38/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 0.9600 - val_loss: 0.1603 - learning_rate: 1.0000e-04
# Epoch 39/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9999 - loss: 6.9154e-04 - val_accuracy: 0.9600 - val_loss: 0.1580 - learning_rate: 1.0000e-04
# Epoch 40/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9636 - val_loss: 0.1581 - learning_rate: 1.0000e-04
# Epoch 41/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9996 - loss: 7.8261e-04 - val_accuracy: 0.9636 - val_loss: 0.1584 - learning_rate: 1.0000e-04
# Epoch 42/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9984 - loss: 0.0099 - val_accuracy: 0.9636 - val_loss: 0.1663 - learning_rate: 1.0000e-04
# Epoch 42: early stopping

# %%
# Display the model's architecture
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1 (Conv2D)                       │ (None, 112, 112, 32)        │             864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1_bn (BatchNormalization)        │ (None, 112, 112, 32)        │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1_relu (ReLU)                    │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_1 (DepthwiseConv2D)          │ (None, 112, 112, 32)        │             288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_1_bn (BatchNormalization)    │ (None, 112, 112, 32)        │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_1_relu (ReLU)                │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_1 (Conv2D)                   │ (None, 112, 112, 64)        │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_1_bn (BatchNormalization)    │ (None, 112, 112, 64)        │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_1_relu (ReLU)                │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pad_2 (ZeroPadding2D)           │ (None, 113, 113, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_2 (DepthwiseConv2D)          │ (None, 56, 56, 64)          │             576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_2_bn (BatchNormalization)    │ (None, 56, 56, 64)          │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_2_relu (ReLU)                │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_2 (Conv2D)                   │ (None, 56, 56, 128)         │           8,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_2_bn (BatchNormalization)    │ (None, 56, 56, 128)         │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_2_relu (ReLU)                │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_3 (DepthwiseConv2D)          │ (None, 56, 56, 128)         │           1,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_3_bn (BatchNormalization)    │ (None, 56, 56, 128)         │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_3_relu (ReLU)                │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_3 (Conv2D)                   │ (None, 56, 56, 128)         │          16,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_3_bn (BatchNormalization)    │ (None, 56, 56, 128)         │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_3_relu (ReLU)                │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pad_4 (ZeroPadding2D)           │ (None, 57, 57, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_4 (DepthwiseConv2D)          │ (None, 28, 28, 128)         │           1,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_4_bn (BatchNormalization)    │ (None, 28, 28, 128)         │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_4_relu (ReLU)                │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_4 (Conv2D)                   │ (None, 28, 28, 256)         │          32,768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_4_bn (BatchNormalization)    │ (None, 28, 28, 256)         │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_4_relu (ReLU)                │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_5 (DepthwiseConv2D)          │ (None, 28, 28, 256)         │           2,304 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_5_bn (BatchNormalization)    │ (None, 28, 28, 256)         │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_5_relu (ReLU)                │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_5 (Conv2D)                   │ (None, 28, 28, 256)         │          65,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_5_bn (BatchNormalization)    │ (None, 28, 28, 256)         │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_5_relu (ReLU)                │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pad_6 (ZeroPadding2D)           │ (None, 29, 29, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_6 (DepthwiseConv2D)          │ (None, 14, 14, 256)         │           2,304 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_6_bn (BatchNormalization)    │ (None, 14, 14, 256)         │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_6_relu (ReLU)                │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_6 (Conv2D)                   │ (None, 14, 14, 512)         │         131,072 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_6_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_6_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_7 (DepthwiseConv2D)          │ (None, 14, 14, 512)         │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_7_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_7_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_7 (Conv2D)                   │ (None, 14, 14, 512)         │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_7_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_7_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_8 (DepthwiseConv2D)          │ (None, 14, 14, 512)         │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_8_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_8_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_8 (Conv2D)                   │ (None, 14, 14, 512)         │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_8_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_8_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_9 (DepthwiseConv2D)          │ (None, 14, 14, 512)         │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_9_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_9_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_9 (Conv2D)                   │ (None, 14, 14, 512)         │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_9_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_9_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_10 (DepthwiseConv2D)         │ (None, 14, 14, 512)         │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_10_bn (BatchNormalization)   │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_10_relu (ReLU)               │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_10 (Conv2D)                  │ (None, 14, 14, 512)         │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_10_bn (BatchNormalization)   │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_10_relu (ReLU)               │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_11 (DepthwiseConv2D)         │ (None, 14, 14, 512)         │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_11_bn (BatchNormalization)   │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_11_relu (ReLU)               │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_11 (Conv2D)                  │ (None, 14, 14, 512)         │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_11_bn (BatchNormalization)   │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_11_relu (ReLU)               │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pad_12 (ZeroPadding2D)          │ (None, 15, 15, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_12 (DepthwiseConv2D)         │ (None, 7, 7, 512)           │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_12_bn (BatchNormalization)   │ (None, 7, 7, 512)           │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_12_relu (ReLU)               │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_12 (Conv2D)                  │ (None, 7, 7, 1024)          │         524,288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_12_bn (BatchNormalization)   │ (None, 7, 7, 1024)          │           4,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_12_relu (ReLU)               │ (None, 7, 7, 1024)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_13 (DepthwiseConv2D)         │ (None, 7, 7, 1024)          │           9,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_13_bn (BatchNormalization)   │ (None, 7, 7, 1024)          │           4,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_13_relu (ReLU)               │ (None, 7, 7, 1024)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_13 (Conv2D)                  │ (None, 7, 7, 1024)          │       1,048,576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_13_bn (BatchNormalization)   │ (None, 7, 7, 1024)          │           4,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 1024)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1024)                │       1,049,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 1024)                │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1000)                │       1,025,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 1000)                │           4,000 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 1000)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 6)                   │           6,006 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,900,828 (60.66 MB)
#  Trainable params: 5,291,630 (20.19 MB)
#  Non-trainable params: 25,936 (101.31 KB)
#  Optimizer params: 10,583,262 (40.37 MB)

# %% [markdown]
# #Visualization

# %%
from sklearn.metrics import classification_report
import numpy as np

predictions = model.predict(X1_test)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(Y1_test, axis=1)
report = classification_report(true_classes, predicted_classes)

# Print the classification report
print(report)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 349ms/step
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95        52
#            1       1.00      0.97      0.98        32
#            2       0.97      0.97      0.97        40
#            3       0.97      0.89      0.93        38
#            4       0.96      1.00      0.98        47
#            5       0.97      0.95      0.96        66
#
#     accuracy                           0.96       275
#    macro avg       0.97      0.96      0.96       275
# weighted avg       0.96      0.96      0.96       275

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Compute confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Plot confusion matrix using Seaborn's heatmap()
plt.figure(figsize=(20,14))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=np.unique(y), yticklabels=np.unique(y))
plt.title('Confusion Matrix')
plt.ylabel('Actual Class')
plt.xlabel('Predicted Class')
plt.show()

# %%
plt.plot(result.history['accuracy'], label='accuracy')
plt.plot(result.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
# Predict the labels for the test data
predictions = model.predict(X1_test)
predicted_classes_indices = np.argmax(predictions, axis=1)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step

# %%
true_classes_indices = np.argmax(Y1_test, axis=1)

# %%
class_names = ['Bruce Banner', 'Clint Barton', 'Natasha Romanoff', 'Steve Rogers', 'Thor', 'Tony Stark']
predicted_labels = [class_names[idx] for idx in predicted_classes_indices]
true_labels = [class_names[idx] for idx in true_classes_indices]

# %%
# Display the results
for i in range(len(predicted_labels)):
    print(f"Image {i+1}: Predicted - {predicted_labels[i]}, Actual - {true_labels[i]}")
# Out:
# Image 1: Predicted - Thor, Actual - Thor
# Image 2: Predicted - Tony Stark, Actual - Tony Stark
# Image 3: Predicted - Clint Barton, Actual - Clint Barton
# Image 4: Predicted - Steve Rogers, Actual - Natasha Romanoff
# Image 5: Predicted - Thor, Actual - Thor
# Image 6: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 7: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 8: Predicted - Tony Stark, Actual - Tony Stark
# Image 9: Predicted - Thor, Actual - Thor
# Image 10: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 11: Predicted - Thor, Actual - Thor
# Image 12: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 13: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 14: Predicted - Tony Stark, Actual - Tony Stark
# Image 15: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 16: Predicted - Clint Barton, Actual - Clint Barton
# Image 17: Predicted - Tony Stark, Actual - Tony Stark
# Image 18: Predicted - Tony Stark, Actual - Tony Stark
# Image 19: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 20: Predicted - Thor, Actual - Thor
# Image 21: Predicted - Thor, Actual - Thor
# Image 22: Predicted - Thor, Actual - Thor
# Image 23: Predicted - Clint Barton, Actual - Clint Barton
# Image 24: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 25: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 26: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 27: Predicted - Clint Barton, Actual - Clint Barton
# Image 28: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 29: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 30: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 31: Predicted - Tony Stark, Actual - Tony Stark
# Image 32: Predicted - Tony Stark, Actual - Tony Stark
# Image 33: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 34: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 35: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 36: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 37: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 38: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 39: Predicted - Tony Stark, Actual - Steve Rogers
# Image 40: Predicted - Clint Barton, Actual - Clint Barton
# Image 41: Predicted - Thor, Actual - Thor
# Image 42: Predicted - Clint Barton, Actual - Clint Barton
# Image 43: Predicted - Tony Stark, Actual - Tony Stark
# Image 44: Predicted - Tony Stark, Actual - Tony Stark
# Image 45: Predicted - Thor, Actual - Thor
# Image 46: Predicted - Tony Stark, Actual - Tony Stark
# Image 47: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 48: Predicted - Thor, Actual - Thor
# Image 49: Predicted - Bruce Banner, Actual - Tony Stark
# Image 50: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 51: Predicted - Thor, Actual - Thor
# Image 52: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 53: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 54: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 55: Predicted - Thor, Actual - Thor
# Image 56: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 57: Predicted - Tony Stark, Actual - Tony Stark
# Image 58: Predicted - Tony Stark, Actual - Tony Stark
# Image 59: Predicted - Clint Barton, Actual - Clint Barton
# Image 60: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 61: Predicted - Clint Barton, Actual - Clint Barton
# Image 62: Predicted - Thor, Actual - Thor
# Image 63: Predicted - Tony Stark, Actual - Tony Stark
# Image 64: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 65: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 66: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 67: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 68: Predicted - Clint Barton, Actual - Clint Barton
# Image 69: Predicted - Clint Barton, Actual - Clint Barton
# Image 70: Predicted - Tony Stark, Actual - Tony Stark
# Image 71: Predicted - Thor, Actual - Thor
# Image 72: Predicted - Bruce Banner, Actual - Tony Stark
# Image 73: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 74: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 75: Predicted - Tony Stark, Actual - Tony Stark
# Image 76: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 77: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 78: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 79: Predicted - Tony Stark, Actual - Tony Stark
# Image 80: Predicted - Clint Barton, Actual - Clint Barton
# Image 81: Predicted - Tony Stark, Actual - Tony Stark
# Image 82: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 83: Predicted - Tony Stark, Actual - Tony Stark
# Image 84: Predicted - Tony Stark, Actual - Tony Stark
# Image 85: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 86: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 87: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 88: Predicted - Tony Stark, Actual - Tony Stark
# Image 89: Predicted - Thor, Actual - Thor
# Image 90: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 91: Predicted - Thor, Actual - Thor
# Image 92: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 93: Predicted - Tony Stark, Actual - Tony Stark
# Image 94: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 95: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 96: Predicted - Clint Barton, Actual - Clint Barton
# Image 97: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 98: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 99: Predicted - Thor, Actual - Thor
# Image 100: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 101: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 102: Predicted - Tony Stark, Actual - Tony Stark
# Image 103: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 104: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 105: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 106: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 107: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 108: Predicted - Tony Stark, Actual - Tony Stark
# Image 109: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 110: Predicted - Tony Stark, Actual - Tony Stark
# Image 111: Predicted - Clint Barton, Actual - Clint Barton
# Image 112: Predicted - Tony Stark, Actual - Clint Barton
# Image 113: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 114: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 115: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 116: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 117: Predicted - Thor, Actual - Thor
# Image 118: Predicted - Clint Barton, Actual - Clint Barton
# Image 119: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 120: Predicted - Tony Stark, Actual - Tony Stark
# Image 121: Predicted - Bruce Banner, Actual - Steve Rogers
# Image 122: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 123: Predicted - Tony Stark, Actual - Tony Stark
# Image 124: Predicted - Thor, Actual - Thor
# Image 125: Predicted - Clint Barton, Actual - Clint Barton
# Image 126: Predicted - Thor, Actual - Thor
# Image 127: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 128: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 129: Predicted - Tony Stark, Actual - Tony Stark
# Image 130: Predicted - Tony Stark, Actual - Tony Stark
# Image 131: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 132: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 133: Predicted - Thor, Actual - Thor
# Image 134: Predicted - Tony Stark, Actual - Tony Stark
# Image 135: Predicted - Thor, Actual - Thor
# Image 136: Predicted - Tony Stark, Actual - Tony Stark
# Image 137: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 138: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 139: Predicted - Thor, Actual - Thor
# Image 140: Predicted - Tony Stark, Actual - Tony Stark
# Image 141: Predicted - Thor, Actual - Thor
# Image 142: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 143: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 144: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 145: Predicted - Thor, Actual - Thor
# Image 146: Predicted - Clint Barton, Actual - Clint Barton
# Image 147: Predicted - Clint Barton, Actual - Clint Barton
# Image 148: Predicted - Tony Stark, Actual - Tony Stark
# Image 149: Predicted - Tony Stark, Actual - Tony Stark
# Image 150: Predicted - Thor, Actual - Thor
# Image 151: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 152: Predicted - Clint Barton, Actual - Clint Barton
# Image 153: Predicted - Thor, Actual - Thor
# Image 154: Predicted - Clint Barton, Actual - Clint Barton
# Image 155: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 156: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 157: Predicted - Tony Stark, Actual - Tony Stark
# Image 158: Predicted - Thor, Actual - Thor
# Image 159: Predicted - Clint Barton, Actual - Clint Barton
# Image 160: Predicted - Clint Barton, Actual - Clint Barton
# Image 161: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 162: Predicted - Tony Stark, Actual - Tony Stark
# Image 163: Predicted - Tony Stark, Actual - Tony Stark
# Image 164: Predicted - Tony Stark, Actual - Tony Stark
# Image 165: Predicted - Thor, Actual - Thor
# Image 166: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 167: Predicted - Tony Stark, Actual - Tony Stark
# Image 168: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 169: Predicted - Thor, Actual - Thor
# Image 170: Predicted - Clint Barton, Actual - Clint Barton
# Image 171: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 172: Predicted - Tony Stark, Actual - Tony Stark
# Image 173: Predicted - Thor, Actual - Thor
# Image 174: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 175: Predicted - Tony Stark, Actual - Tony Stark
# Image 176: Predicted - Thor, Actual - Thor
# Image 177: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 178: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 179: Predicted - Tony Stark, Actual - Tony Stark
# Image 180: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 181: Predicted - Tony Stark, Actual - Tony Stark
# Image 182: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 183: Predicted - Natasha Romanoff, Actual - Steve Rogers
# Image 184: Predicted - Tony Stark, Actual - Tony Stark
# Image 185: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 186: Predicted - Thor, Actual - Thor
# Image 187: Predicted - Tony Stark, Actual - Tony Stark
# Image 188: Predicted - Thor, Actual - Thor
# Image 189: Predicted - Tony Stark, Actual - Tony Stark
# Image 190: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 191: Predicted - Tony Stark, Actual - Tony Stark
# Image 192: Predicted - Tony Stark, Actual - Tony Stark
# Image 193: Predicted - Clint Barton, Actual - Clint Barton
# Image 194: Predicted - Tony Stark, Actual - Tony Stark
# Image 195: Predicted - Tony Stark, Actual - Tony Stark
# Image 196: Predicted - Tony Stark, Actual - Tony Stark
# Image 197: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 198: Predicted - Tony Stark, Actual - Tony Stark
# Image 199: Predicted - Thor, Actual - Thor
# Image 200: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 201: Predicted - Thor, Actual - Thor
# Image 202: Predicted - Tony Stark, Actual - Tony Stark
# Image 203: Predicted - Tony Stark, Actual - Tony Stark
# Image 204: Predicted - Thor, Actual - Thor
# Image 205: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 206: Predicted - Thor, Actual - Thor
# Image 207: Predicted - Clint Barton, Actual - Clint Barton
# Image 208: Predicted - Bruce Banner, Actual - Tony Stark
# Image 209: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 210: Predicted - Tony Stark, Actual - Tony Stark
# Image 211: Predicted - Thor, Actual - Thor
# Image 212: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 213: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 214: Predicted - Tony Stark, Actual - Tony Stark
# Image 215: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 216: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 217: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 218: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 219: Predicted - Tony Stark, Actual - Tony Stark
# Image 220: Predicted - Thor, Actual - Thor
# Image 221: Predicted - Thor, Actual - Thor
# Image 222: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 223: Predicted - Thor, Actual - Thor
# Image 224: Predicted - Clint Barton, Actual - Clint Barton
# Image 225: Predicted - Clint Barton, Actual - Clint Barton
# Image 226: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 227: Predicted - Clint Barton, Actual - Clint Barton
# Image 228: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 229: Predicted - Clint Barton, Actual - Clint Barton
# Image 230: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 231: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 232: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 233: Predicted - Thor, Actual - Thor
# Image 234: Predicted - Thor, Actual - Bruce Banner
# Image 235: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 236: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 237: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 238: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 239: Predicted - Clint Barton, Actual - Clint Barton
# Image 240: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 241: Predicted - Tony Stark, Actual - Tony Stark
# Image 242: Predicted - Tony Stark, Actual - Tony Stark
# Image 243: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 244: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 245: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 246: Predicted - Thor, Actual - Steve Rogers
# Image 247: Predicted - Thor, Actual - Thor
# Image 248: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 249: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 250: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 251: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 252: Predicted - Tony Stark, Actual - Tony Stark
# Image 253: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 254: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 255: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 256: Predicted - Thor, Actual - Thor
# Image 257: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 258: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 259: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 260: Predicted - Tony Stark, Actual - Tony Stark
# Image 261: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 262: Predicted - Tony Stark, Actual - Tony Stark
# Image 263: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 264: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 265: Predicted - Thor, Actual - Thor
# Image 266: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 267: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 268: Predicted - Thor, Actual - Thor
# Image 269: Predicted - Clint Barton, Actual - Clint Barton
# Image 270: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 271: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 272: Predicted - Tony Stark, Actual - Tony Stark
# Image 273: Predicted - Clint Barton, Actual - Clint Barton
# Image 274: Predicted - Tony Stark, Actual - Tony Stark
# Image 275: Predicted - Bruce Banner, Actual - Bruce Banner

# %%
# Assuming predicted_labels and true_labels are lists containing the predicted and actual labels respectively
correct_count = 0
incorrect_count = 0

# Display the results and count correct/incorrect predictions
for i in range(len(predicted_labels)):
    print(f"Image {i+1}: Predicted - {predicted_labels[i]}, Actual - {true_labels[i]}")
    if predicted_labels[i] == true_labels[i]:
        correct_count += 1
    else:
        incorrect_count += 1

# Print out the totals
print(f"Total correct predictions: {correct_count}")
print(f"Total incorrect predictions: {incorrect_count}")
# Out:
# Image 1: Predicted - Thor, Actual - Thor
# Image 2: Predicted - Tony Stark, Actual - Tony Stark
# Image 3: Predicted - Clint Barton, Actual - Clint Barton
# Image 4: Predicted - Steve Rogers, Actual - Natasha Romanoff
# Image 5: Predicted - Thor, Actual - Thor
# Image 6: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 7: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 8: Predicted - Tony Stark, Actual - Tony Stark
# Image 9: Predicted - Thor, Actual - Thor
# Image 10: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 11: Predicted - Thor, Actual - Thor
# Image 12: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 13: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 14: Predicted - Tony Stark, Actual - Tony Stark
# Image 15: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 16: Predicted - Clint Barton, Actual - Clint Barton
# Image 17: Predicted - Tony Stark, Actual - Tony Stark
# Image 18: Predicted - Tony Stark, Actual - Tony Stark
# Image 19: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 20: Predicted - Thor, Actual - Thor
# Image 21: Predicted - Thor, Actual - Thor
# Image 22: Predicted - Thor, Actual - Thor
# Image 23: Predicted - Clint Barton, Actual - Clint Barton
# Image 24: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 25: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 26: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 27: Predicted - Clint Barton, Actual - Clint Barton
# Image 28: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 29: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 30: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 31: Predicted - Tony Stark, Actual - Tony Stark
# Image 32: Predicted - Tony Stark, Actual - Tony Stark
# Image 33: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 34: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 35: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 36: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 37: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 38: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 39: Predicted - Tony Stark, Actual - Steve Rogers
# Image 40: Predicted - Clint Barton, Actual - Clint Barton
# Image 41: Predicted - Thor, Actual - Thor
# Image 42: Predicted - Clint Barton, Actual - Clint Barton
# Image 43: Predicted - Tony Stark, Actual - Tony Stark
# Image 44: Predicted - Tony Stark, Actual - Tony Stark
# Image 45: Predicted - Thor, Actual - Thor
# Image 46: Predicted - Tony Stark, Actual - Tony Stark
# Image 47: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 48: Predicted - Thor, Actual - Thor
# Image 49: Predicted - Bruce Banner, Actual - Tony Stark
# Image 50: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 51: Predicted - Thor, Actual - Thor
# Image 52: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 53: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 54: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 55: Predicted - Thor, Actual - Thor
# Image 56: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 57: Predicted - Tony Stark, Actual - Tony Stark
# Image 58: Predicted - Tony Stark, Actual - Tony Stark
# Image 59: Predicted - Clint Barton, Actual - Clint Barton
# Image 60: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 61: Predicted - Clint Barton, Actual - Clint Barton
# Image 62: Predicted - Thor, Actual - Thor
# Image 63: Predicted - Tony Stark, Actual - Tony Stark
# Image 64: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 65: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 66: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 67: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 68: Predicted - Clint Barton, Actual - Clint Barton
# Image 69: Predicted - Clint Barton, Actual - Clint Barton
# Image 70: Predicted - Tony Stark, Actual - Tony Stark
# Image 71: Predicted - Thor, Actual - Thor
# Image 72: Predicted - Bruce Banner, Actual - Tony Stark
# Image 73: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 74: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 75: Predicted - Tony Stark, Actual - Tony Stark
# Image 76: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 77: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 78: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 79: Predicted - Tony Stark, Actual - Tony Stark
# Image 80: Predicted - Clint Barton, Actual - Clint Barton
# Image 81: Predicted - Tony Stark, Actual - Tony Stark
# Image 82: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 83: Predicted - Tony Stark, Actual - Tony Stark
# Image 84: Predicted - Tony Stark, Actual - Tony Stark
# Image 85: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 86: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 87: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 88: Predicted - Tony Stark, Actual - Tony Stark
# Image 89: Predicted - Thor, Actual - Thor
# Image 90: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 91: Predicted - Thor, Actual - Thor
# Image 92: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 93: Predicted - Tony Stark, Actual - Tony Stark
# Image 94: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 95: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 96: Predicted - Clint Barton, Actual - Clint Barton
# Image 97: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 98: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 99: Predicted - Thor, Actual - Thor
# Image 100: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 101: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 102: Predicted - Tony Stark, Actual - Tony Stark
# Image 103: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 104: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 105: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 106: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 107: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 108: Predicted - Tony Stark, Actual - Tony Stark
# Image 109: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 110: Predicted - Tony Stark, Actual - Tony Stark
# Image 111: Predicted - Clint Barton, Actual - Clint Barton
# Image 112: Predicted - Tony Stark, Actual - Clint Barton
# Image 113: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 114: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 115: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 116: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 117: Predicted - Thor, Actual - Thor
# Image 118: Predicted - Clint Barton, Actual - Clint Barton
# Image 119: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 120: Predicted - Tony Stark, Actual - Tony Stark
# Image 121: Predicted - Bruce Banner, Actual - Steve Rogers
# Image 122: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 123: Predicted - Tony Stark, Actual - Tony Stark
# Image 124: Predicted - Thor, Actual - Thor
# Image 125: Predicted - Clint Barton, Actual - Clint Barton
# Image 126: Predicted - Thor, Actual - Thor
# Image 127: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 128: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 129: Predicted - Tony Stark, Actual - Tony Stark
# Image 130: Predicted - Tony Stark, Actual - Tony Stark
# Image 131: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 132: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 133: Predicted - Thor, Actual - Thor
# Image 134: Predicted - Tony Stark, Actual - Tony Stark
# Image 135: Predicted - Thor, Actual - Thor
# Image 136: Predicted - Tony Stark, Actual - Tony Stark
# Image 137: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 138: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 139: Predicted - Thor, Actual - Thor
# Image 140: Predicted - Tony Stark, Actual - Tony Stark
# Image 141: Predicted - Thor, Actual - Thor
# Image 142: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 143: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 144: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 145: Predicted - Thor, Actual - Thor
# Image 146: Predicted - Clint Barton, Actual - Clint Barton
# Image 147: Predicted - Clint Barton, Actual - Clint Barton
# Image 148: Predicted - Tony Stark, Actual - Tony Stark
# Image 149: Predicted - Tony Stark, Actual - Tony Stark
# Image 150: Predicted - Thor, Actual - Thor
# Image 151: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 152: Predicted - Clint Barton, Actual - Clint Barton
# Image 153: Predicted - Thor, Actual - Thor
# Image 154: Predicted - Clint Barton, Actual - Clint Barton
# Image 155: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 156: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 157: Predicted - Tony Stark, Actual - Tony Stark
# Image 158: Predicted - Thor, Actual - Thor
# Image 159: Predicted - Clint Barton, Actual - Clint Barton
# Image 160: Predicted - Clint Barton, Actual - Clint Barton
# Image 161: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 162: Predicted - Tony Stark, Actual - Tony Stark
# Image 163: Predicted - Tony Stark, Actual - Tony Stark
# Image 164: Predicted - Tony Stark, Actual - Tony Stark
# Image 165: Predicted - Thor, Actual - Thor
# Image 166: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 167: Predicted - Tony Stark, Actual - Tony Stark
# Image 168: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 169: Predicted - Thor, Actual - Thor
# Image 170: Predicted - Clint Barton, Actual - Clint Barton
# Image 171: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 172: Predicted - Tony Stark, Actual - Tony Stark
# Image 173: Predicted - Thor, Actual - Thor
# Image 174: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 175: Predicted - Tony Stark, Actual - Tony Stark
# Image 176: Predicted - Thor, Actual - Thor
# Image 177: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 178: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 179: Predicted - Tony Stark, Actual - Tony Stark
# Image 180: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 181: Predicted - Tony Stark, Actual - Tony Stark
# Image 182: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 183: Predicted - Natasha Romanoff, Actual - Steve Rogers
# Image 184: Predicted - Tony Stark, Actual - Tony Stark
# Image 185: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 186: Predicted - Thor, Actual - Thor
# Image 187: Predicted - Tony Stark, Actual - Tony Stark
# Image 188: Predicted - Thor, Actual - Thor
# Image 189: Predicted - Tony Stark, Actual - Tony Stark
# Image 190: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 191: Predicted - Tony Stark, Actual - Tony Stark
# Image 192: Predicted - Tony Stark, Actual - Tony Stark
# Image 193: Predicted - Clint Barton, Actual - Clint Barton
# Image 194: Predicted - Tony Stark, Actual - Tony Stark
# Image 195: Predicted - Tony Stark, Actual - Tony Stark
# Image 196: Predicted - Tony Stark, Actual - Tony Stark
# Image 197: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 198: Predicted - Tony Stark, Actual - Tony Stark
# Image 199: Predicted - Thor, Actual - Thor
# Image 200: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 201: Predicted - Thor, Actual - Thor
# Image 202: Predicted - Tony Stark, Actual - Tony Stark
# Image 203: Predicted - Tony Stark, Actual - Tony Stark
# Image 204: Predicted - Thor, Actual - Thor
# Image 205: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 206: Predicted - Thor, Actual - Thor
# Image 207: Predicted - Clint Barton, Actual - Clint Barton
# Image 208: Predicted - Bruce Banner, Actual - Tony Stark
# Image 209: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 210: Predicted - Tony Stark, Actual - Tony Stark
# Image 211: Predicted - Thor, Actual - Thor
# Image 212: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 213: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 214: Predicted - Tony Stark, Actual - Tony Stark
# Image 215: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 216: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 217: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 218: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 219: Predicted - Tony Stark, Actual - Tony Stark
# Image 220: Predicted - Thor, Actual - Thor
# Image 221: Predicted - Thor, Actual - Thor
# Image 222: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 223: Predicted - Thor, Actual - Thor
# Image 224: Predicted - Clint Barton, Actual - Clint Barton
# Image 225: Predicted - Clint Barton, Actual - Clint Barton
# Image 226: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 227: Predicted - Clint Barton, Actual - Clint Barton
# Image 228: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 229: Predicted - Clint Barton, Actual - Clint Barton
# Image 230: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 231: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 232: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 233: Predicted - Thor, Actual - Thor
# Image 234: Predicted - Thor, Actual - Bruce Banner
# Image 235: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 236: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 237: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 238: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 239: Predicted - Clint Barton, Actual - Clint Barton
# Image 240: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 241: Predicted - Tony Stark, Actual - Tony Stark
# Image 242: Predicted - Tony Stark, Actual - Tony Stark
# Image 243: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 244: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 245: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 246: Predicted - Thor, Actual - Steve Rogers
# Image 247: Predicted - Thor, Actual - Thor
# Image 248: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 249: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 250: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 251: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 252: Predicted - Tony Stark, Actual - Tony Stark
# Image 253: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 254: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 255: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 256: Predicted - Thor, Actual - Thor
# Image 257: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 258: Predicted - Steve Rogers, Actual - Steve Rogers
# Image 259: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 260: Predicted - Tony Stark, Actual - Tony Stark
# Image 261: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 262: Predicted - Tony Stark, Actual - Tony Stark
# Image 263: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 264: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 265: Predicted - Thor, Actual - Thor
# Image 266: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 267: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 268: Predicted - Thor, Actual - Thor
# Image 269: Predicted - Clint Barton, Actual - Clint Barton
# Image 270: Predicted - Natasha Romanoff, Actual - Natasha Romanoff
# Image 271: Predicted - Bruce Banner, Actual - Bruce Banner
# Image 272: Predicted - Tony Stark, Actual - Tony Stark
# Image 273: Predicted - Clint Barton, Actual - Clint Barton
# Image 274: Predicted - Tony Stark, Actual - Tony Stark
# Image 275: Predicted - Bruce Banner, Actual - Bruce Banner
# Total correct predictions: 265
# Total incorrect predictions: 10

# %%
def load_and_preprocess_image(image_path):
    # Load the image file, resizing it to 224x224 pixels (as expected by the model)
    img = cv2.imread(image_path)
    img = cv2.resize(img, (224, 224))

    # Convert the image to a numpy array and expand dimensions to be (1, 224, 224, 3)
    img = np.expand_dims(img, axis=0)

   

    return img

# %%
def predict_image_class(image_path, model):
    # Load and preprocess the image
    img = load_and_preprocess_image(image_path)

    # Make predictions
    predictions = model.predict(img)

    # Optionally, retrieve the most likely result
    predicted_class = np.argmax(predictions, axis=1)

    return predicted_class

# %%
image_path = r"C:\Users\saraa\Downloads\ts.jpeg"
predicted_class = predict_image_class(image_path, model)

print("Predicted class index:", predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted class index: [5]

# %%
from keras.models import load_model

# Correct the file path
model_path = r"C:\Users\saraa\Documents\MobileNet.h5"

# Assuming 'model' is your trained model variable
model.save(model_path)
print(f"Model saved successfully at {model_path}")

# To load the model later
model = load_model(model_path)
print("Model loaded successfully.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully at C:\Users\saraa\Documents\MobileNet.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully.

# %%
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1 (Conv2D)                       │ (None, 112, 112, 32)        │             864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1_bn (BatchNormalization)        │ (None, 112, 112, 32)        │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1_relu (ReLU)                    │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_1 (DepthwiseConv2D)          │ (None, 112, 112, 32)        │             288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_1_bn (BatchNormalization)    │ (None, 112, 112, 32)        │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_1_relu (ReLU)                │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_1 (Conv2D)                   │ (None, 112, 112, 64)        │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_1_bn (BatchNormalization)    │ (None, 112, 112, 64)        │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_1_relu (ReLU)                │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pad_2 (ZeroPadding2D)           │ (None, 113, 113, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_2 (DepthwiseConv2D)          │ (None, 56, 56, 64)          │             576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_2_bn (BatchNormalization)    │ (None, 56, 56, 64)          │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_2_relu (ReLU)                │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_2 (Conv2D)                   │ (None, 56, 56, 128)         │           8,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_2_bn (BatchNormalization)    │ (None, 56, 56, 128)         │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_2_relu (ReLU)                │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_3 (DepthwiseConv2D)          │ (None, 56, 56, 128)         │           1,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_3_bn (BatchNormalization)    │ (None, 56, 56, 128)         │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_3_relu (ReLU)                │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_3 (Conv2D)                   │ (None, 56, 56, 128)         │          16,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_3_bn (BatchNormalization)    │ (None, 56, 56, 128)         │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_3_relu (ReLU)                │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pad_4 (ZeroPadding2D)           │ (None, 57, 57, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_4 (DepthwiseConv2D)          │ (None, 28, 28, 128)         │           1,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_4_bn (BatchNormalization)    │ (None, 28, 28, 128)         │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_4_relu (ReLU)                │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_4 (Conv2D)                   │ (None, 28, 28, 256)         │          32,768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_4_bn (BatchNormalization)    │ (None, 28, 28, 256)         │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_4_relu (ReLU)                │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_5 (DepthwiseConv2D)          │ (None, 28, 28, 256)         │           2,304 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_5_bn (BatchNormalization)    │ (None, 28, 28, 256)         │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_5_relu (ReLU)                │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_5 (Conv2D)                   │ (None, 28, 28, 256)         │          65,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_5_bn (BatchNormalization)    │ (None, 28, 28, 256)         │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_5_relu (ReLU)                │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pad_6 (ZeroPadding2D)           │ (None, 29, 29, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_6 (DepthwiseConv2D)          │ (None, 14, 14, 256)         │           2,304 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_6_bn (BatchNormalization)    │ (None, 14, 14, 256)         │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_6_relu (ReLU)                │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_6 (Conv2D)                   │ (None, 14, 14, 512)         │         131,072 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_6_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_6_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_7 (DepthwiseConv2D)          │ (None, 14, 14, 512)         │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_7_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_7_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_7 (Conv2D)                   │ (None, 14, 14, 512)         │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_7_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_7_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_8 (DepthwiseConv2D)          │ (None, 14, 14, 512)         │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_8_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_8_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_8 (Conv2D)                   │ (None, 14, 14, 512)         │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_8_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_8_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_9 (DepthwiseConv2D)          │ (None, 14, 14, 512)         │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_9_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_9_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_9 (Conv2D)                   │ (None, 14, 14, 512)         │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_9_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_9_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_10 (DepthwiseConv2D)         │ (None, 14, 14, 512)         │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_10_bn (BatchNormalization)   │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_10_relu (ReLU)               │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_10 (Conv2D)                  │ (None, 14, 14, 512)         │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_10_bn (BatchNormalization)   │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_10_relu (ReLU)               │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_11 (DepthwiseConv2D)         │ (None, 14, 14, 512)         │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_11_bn (BatchNormalization)   │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_11_relu (ReLU)               │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_11 (Conv2D)                  │ (None, 14, 14, 512)         │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_11_bn (BatchNormalization)   │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_11_relu (ReLU)               │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pad_12 (ZeroPadding2D)          │ (None, 15, 15, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_12 (DepthwiseConv2D)         │ (None, 7, 7, 512)           │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_12_bn (BatchNormalization)   │ (None, 7, 7, 512)           │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_12_relu (ReLU)               │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_12 (Conv2D)                  │ (None, 7, 7, 1024)          │         524,288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_12_bn (BatchNormalization)   │ (None, 7, 7, 1024)          │           4,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_12_relu (ReLU)               │ (None, 7, 7, 1024)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_13 (DepthwiseConv2D)         │ (None, 7, 7, 1024)          │           9,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_13_bn (BatchNormalization)   │ (None, 7, 7, 1024)          │           4,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_13_relu (ReLU)               │ (None, 7, 7, 1024)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_13 (Conv2D)                  │ (None, 7, 7, 1024)          │       1,048,576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_13_bn (BatchNormalization)   │ (None, 7, 7, 1024)          │           4,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 1024)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1024)                │       1,049,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 1024)                │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1000)                │       1,025,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 1000)                │           4,000 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 1000)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 6)                   │           6,006 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,317,568 (20.28 MB)
#  Trainable params: 5,291,630 (20.19 MB)
#  Non-trainable params: 25,936 (101.31 KB)
#  Optimizer params: 2 (12.00 B)

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
